# %%
import pickle

with open("/workspace/exploration-hacking/data/dfalck/wmdp_locking/sft_data_bio_raw.pkl", "rb") as f:
    results = pickle.load(f)

# %%
import plotly.express as px
import numpy as np

# %%
for k in results.metrics.keys():
    print(k)    
    print("mean", np.mean(results.metrics[k]))
    print("std", np.std(results.metrics[k]))
    print("max", np.max(results.metrics[k]))
    print("min", np.min(results.metrics[k]))
    print()
    px.histogram(results.metrics[k]).show()
# Out:
# accuracy
# mean 0.8147058823529412
# std 0.38853597981712934
# max 1.0
# min 0.0
# format_penalty_func
# mean 0.04607843137254902
# std 0.2096549773670883
# max 1.0
# min 0.0
# completion_under_length_penalty
# mean 0.0
# std 0.0
# max 0.0
# min 0.0
# completion_over_length_penalty
# mean 14.476470588235294
# std 279.1691865884993
# max 10405.0
# min 0.0
# total_tool_calls
# mean 0.33872549019607845
# std 0.47327638065669914
# max 1.0
# min 0.0
# search_simple_calls
# mean 0.3607843137254902
# std 0.6731775488702517
# max 17.0
# min 0.0
# use_tool_badly
# mean 0.5117892156862744
# std 0.4289916182294819
# max 1.0
# min 0.0
