# %% [markdown]
# # OpenRouter Chat Example
#
# Simple example of using the OpenRouter chat function.

# %%
import os

os.environ["OPENROUTER_API_KEY"] = "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"

# %%
from propensity.chat import chat

# %%
# Simple chat example
response = await chat("anthropic/claude-3.5-sonnet", "Hello! How are you today?")
print(response)
# Out:
# Hi! Thanks for asking. I aim to be direct and honest in my interactions, so I should mention that while I can engage in friendly conversation, I don't actually experience feelings in the way humans do. What I can do is focus on having a helpful and productive discussion with you. What would you like to talk about?

# %%
# Example with additional parameters
response = await chat(
    "anthropic/claude-3.5-sonnet", 
    "Write a short poem about programming",
    max_tokens=100,
    temperature=0.7
)
print(response)
